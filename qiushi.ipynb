# %%
import requests
import re
headers = {'User-Agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Mobile Safari/537.36'}
info_lists = []
def judgment_sex(class_name):
    if class_name == 'womenIcon':
        return '女'
    else:
        return '男'
def get_info(url):
    res = requests.get(url)
    ids = re.findall('<h2>(.*?)</h2>',res.text,re.S)#用户名
    levels = re.findall('<div class="articleGender \D+Icon">(.*?)</div>',res.text,re.S)#等级
    sexs = re.findall('<div class="articleGender (.*?)">',res.text,re.S)#性别
    contents = re.findall('<div class="content">.*?<span>(.*?)</span>',res.text,re.S)
    #内容，.*?匹配空行
    laughs = re.findall('<span class="stats-vote"><i class="number">(\d+)</i>',res.text,re.S)
    comments = re.findall('<i class="number">(\d+)</i> 评论',res.text,re.S)
    for id,level,sex,content,laugh,comment in zip(ids,levels,sexs,contents,laughs,comments):
        data = {
            'id':id.strip(),
            'level':level,
            'sex':judgment_sex(sex),
            'content':content.strip(),
            'laugh':laugh,
            'comment':comment
        }
        info_lists.append(data)
urls = ['https://www.qiushibaike.com/text/page/{}/'.format(str(i)) for i in range(1,36)]
for url in urls:
    get_info(url)
print(info_lists)
# 写入到txt文件

for info_list in info_lists:
    fw = open("./qiushi.txt",'a+')
    try:
        fw.write(info_list['id']+'\n')
        fw.write(info_list['level']+'\n')
        fw.write(info_list['sex']+'\n')
        fw.write(info_list['content']+'\n')
        fw.write(info_list['laugh']+'\n')
        fw.write(info_list['comment']+'\n\n')
    except UnicodeEncodeError:
        pass
# Out:
# [{'id': '九头纪', 'level': '82', 'sex': '男', 'content': '家有小正太一枚，特别爱吃果冻。<br/>有次带他逛超市，经过在一大堆***的果冻时当场就定住了，怎么也拉不走。我指着理货员说：“仔仔，妈妈没有带钱，怎么办呢？你实在要吃，就把你押给叔叔吧！”他偏着头想了一会儿，脆生生的说“叔叔，我妈妈没有钱买果冻，我把她押在这里好吗?等我长大赚钱了再来取........... 长大赚钱了再来取........我当场就抓 狂了，顾不上理货员诧异的表情，我一把抓起他飞溜闪人。 儿子啊！难道老妈就只值几个果冻？~~~', 'laugh': '679', 'comment': '5'}, {'id': '奋斗小青年苏苏', 'level': '26', 'sex': '男', 'content': '之前有个同事 转行去做厨   手艺越来越好   他老板和老板娘相识前  两家都是开饭店的   店还连一起   后来因为互相照应就在一起了  饭店也并成了一个      最近两人闹离婚   竟然问我同事 他们离婚以后 要跟谁  跟谁  谁。。。。。\x01[面瘫神]', 'laugh': '3204', 'comment': '30'}, {'id': '屌丝屌好刁', 'level': '29', 'sex': '男', 'content': '很多很多年以前，有一个词叫“网瘾”，是人们心目中洪水猛兽一样的东西，要被关起来强行治疗的。后来有了智能手机，大家更患上了网瘾，就没人再提治疗的事儿了。。。 \u200b\u200b\u200b', 'laugh': '1995', 'comment': '26'}, {'id': '路远马亡0', 'level': '24', 'sex': '女', 'content': '每次去买肉，老板来20块钱的
。\x01[晚安睡觉]', 'laugh': '2155', 'comment': '43'}, {'id': '秋风中的恶之花', 'level': '94', 'sex': '女', 'content': '高中那会，暗恋我同桌。高二分班后，放假时间骤减，加上文理科不同楼，平时除了课间操，几乎都看不到他。<br/>思念无处安放，有天特意起了个早。我偷溜进他教室，趴在他桌上，一张一张翻阅他的数学作业本。<br/>一抬头，一张朝思暮想的脸映入眼帘。我瞬间慌了神，结结巴巴的解释：“我，我想借你作业抄抄。”<br/>同桌明显愣了一下：“咱们都分班了，你还来抄啥作业？”<br/>尼玛……', 'laugh': '1984', 'comment': '41'}, {'id': '九头纪', 'level': '82', 'sex': '男', 'content': '话说小妞我还是小奶娃子的时候，整晚都要哭啊吵啊的……<br/>每次这时候我妈就支使老爹来哄我，<br/>到我出生第50天的那晚上，<br/>嘿 ，不哭不吵，<br/>我爹一个激灵醒了 : 咱闺女今晚咋没声了。<br/>据老爹自己说他当时一个鲤鱼打挺就起来了、<br/>颤抖的、忐忑的、 探了探我的鼻息，<br/>“哦、还活着”。', 'laugh': '2416', 'comment': '36'}, {'id': '穆尚夜', 'level': '27', 'sex': '女', 'content': '当一个人走进你心里，其余的人都要被赶出去，这就是爱。<br/>\xa0<br/>“老公，跟我念，我\xa0是\xa0女\xa0的\xa0。”<br/>\xa0<br/>“不，我是你的。”', 'laugh': '422', 'comment': '0'}, {'id': '又一盏素酒', 'level': '35', 'sex': '男', 'content': '&quot;早上和老公把儿子送到幼儿园，儿子哭闹不休不让我们走，最后一狠心甩开他的手就走了。<br/>这时儿子在后面大叫：“你们这对狗男女。”&quot;', 'laugh': '4050', 'comment': '42'}, {'id': '哈和嗨', 'level': '31', 'sex': '男', 'content': '记得结婚时，去接媳妇，要给岳父敬茶。紧张的我说了一句：爸，我来娶您媳妇了。嘈杂的屋内顿时安静了，明显看到岳父嘴角抽搐了一下。', 'laugh': '3068', 'comment': '23'}, {'id': '我不是王小蕾', 'level': '23', 'sex': '女', 'content': '快三岁的闺女想买平衡车，于是就跟他爸爸要钱。<br/>然后老公嫌家里车太多，闺女愣是怎么恳求，他也不答应 ！<br/>然后闺女就跑我这边了，我以为她又要开始求我呢~谁知道，她对我说，“麻麻，粑粑说你黑，说你胖，说你好丑！”', 'laugh': '2888', 'comment': '42'}, {'id': '*波妞*', 'level': '26', 'sex': '女', 'content': '小时候听周杰伦的《双截棍》可喜欢了，就偷偷存了压岁钱去买，刚拿到手的时候，我耍的那叫一个厉害，虎虎生威，卖双截棍的老板看到都害怕，最后也没收我的钱，还拿了一百块给我，说我是个狠人，让我去医院看看我满头的包。这么多年过去了，我一直怀疑双截棍是医院发明的', 'laugh': '1952', 'comment': '29'}, {'id': '自带冷场特效丶', 'level': '27', 'sex': '男', 'content': '好久不来，不知道现在还割不割了。今天收拾东西，我有一个泡澡 ...
